# %% [markdown]
# # Using Gadfly (`ggplot2`) for producing plots

# %% [markdown]
# We will briefly discuss how to use the `Gadfly` package to produce plots in Julia.

# %%
using Gadfly
# Out:
# INFO: Recompiling stale cache file /Users/jmxp/.julia/lib/v0.4/Gadfly.ji for module Gadfly.

# %% [markdown]
# ## Basic plots

# %%
plot(x=rand(10),y=rand(10), Geom.point, Geom.line)
# Out:
# Plot(...)

# %%
plot(x=rand(10),y=rand(10))
# Out:
# Plot(...)

# %%
plot([sin, cos], 0, 6.2832)
# Out:
# Plot(...)

# %% [markdown]
# ## Plotting data frames

# %%
using RDatasets
# Out:
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /Users/jmxp/.julia/v0.4/RDatasets/src/dataset.jl:1
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /Users/jmxp/.julia/v0.4/RDatasets/src/dataset.jl:1
# WARNING: Base.String is deprecated, use AbstractString instead.
#   likely near /Users/jmxp/.julia/v0.4/RDatasets/src/datasets.jl:1

# %%
plot(dataset("datasets", "iris"), x="PetalLength", y="PetalWidth", Geom.point)
# Out:
# Plot(...)

# %%
plot(dataset("datasets", "iris"), x="SepalLength", color="Species", Geom.histogram)
# Out:
# Plot(...)

# %%
plot(dataset("datasets", "iris"), x="SepalLength", color="Species", Geom.density)
# Out:
# Plot(...)

# %% [markdown]
# ## Saving plots as image files

# %%
q=plot(dataset("datasets", "iris"), x="SepalLength", color="Species", Geom.density);

# %%
draw(PNG("myplot.png", 12cm, 6cm), q)

# %% [markdown]
# Note that this requires the Cairo package as well as the FontConfig package.
